# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
#서울 지역 건물 폴리곤 파일 입력
seoul_area = gpd.GeoDataFrame.from_file('F_FAC_BUILDING_11_202103.shp', encoding='cp949')

# %%
#서울 지역 첫번째 건물 시각화
seoul_area.geometry[123].boundary

# %%
#서울 지역 첫번째 건물 중심점 시각화
df1=seoul_area.geometry[123].boundary
df2=seoul_area.geometry[123].centroid
df1.union(df2)

# %%
#서울지역 건물 시각화
seoul_area.geometry.boundary.plot()
plt.show()

# %%
#plt 초기화
plt.clf()
